# %%
from random import choice
import random

class Question:
     def __init__(self,prompt,answer):
            self.prompt = prompt
            self.answer = answer

question_prompts =open ("quiz.txt", "r") 
content = question_prompts.read()

questions = [
    Question(content[1:109],"C"),
    Question(content[109:328],"A"),
    Question(content[328:508],"A"),
    Question(content[508:645],"D"),
    Question(content[645:818],"A"),
    Question(content[818:1020],"B"),
    Question(content[1020:1150],"A"),
    Question(content[1150:1364],"D"),
    Question(content[1364:1561],"B"),
    Question(content[1561:1699],"A"),   
]     
random.shuffle(questions)
             

def run_quiz(questions):
    score=0
    for question in questions:
        answer= input(question.prompt)
        if answer == question.answer:
             score += 1
    print("you got", score, "out of", len(questions))
    if score >= 7:
        print("Congruats your Pass")
    else:
        print("Better luck next time")
def main_menu():
    print("+-----------------------------------+")
    print("|      WELCOME TO QUIZ MASTER       |")
    print("+-----------------------------------+")
    print("|Please selection an option         |")
    print("|                                   |")
    print("| 1. Play a Quiz                    |")
    print("| 0. Quit                           |")
    print("+-----------------------------------+")
    choice = input("Enter 0,1: ")
    if choice == '1':
        run_quiz(questions)
    else:
        Quit()
main_menu()
# Out:
# +-----------------------------------+
# |      WELCOME TO QUIZ MASTER       |
# +-----------------------------------+
# |Please selection an option         |
# |                                   |
# | 1. Play a Quiz                    |
# | 0. Quit                           |
# +-----------------------------------+
# Enter 0,1: 1
#
# Q.  They were all shocked at his failure in the competition.
#     A.were shocked at all
#     B.had all shocked at
#     C.had all shocked by
#     D.had been all shocked on
#
# A
#
# Q.  The man to who I sold my house was a cheat.
#     A.to whom I sell
#     B.to who I sell
#     C.who was sold to
#     D.to whom I sold
# A
# Q.  Why did you not threw the bag away?
#     A.did you not throw
#     B.had you not threw
#     C.did you not thrown
#     D.you did not thrown
# A
#
# Q.  You need not come unless you want to.
#     A.You don't need to come unless you want to
#     B.You come only when you want to
#     C.You come unless you don't want to
# ...
